# %% [markdown]
# # **XCS224N - A5**
#
# [![Open In Google Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/scpd-proed/XCS224N-A5/blob/main/src/Google_Colab_XCS224N_A5.ipynb)
#
# Before opening the notebook with the badge, you would need to allow Google Colab to access the GitHub private repositories. Please check therefore [this tutorial](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb#:~:text=Navigate%20to%20http%3A%2F%2Fcolab,to%20read%20the%20private%20files.).

# %% [markdown]
# In this Notebook, using GitHub and Google Services(Drive, Colab Pro) we will be leveraging the GPU to train our models and generate the files required by our grader.
#
# **Note**: to successfully run the experiments on Google Colab you would need at least the Pro subscription, that gives you access to more powerfull GPUs, Network and Storage and no timeouts will occur when session is left running!
#
# Please **read carefully** and follow the instructions from the next cells.
#
# For any issues please contact your Course Facilitator!

# %% [markdown]
# ## Install required tools

# %%
# !pip install --upgrade timeout_decorator==0.5.0
# !pip install --upgrade numpy==2.4.4
# !pip install --upgrade scipy==1.17.1
# !pip install --upgrade scikit-learn==1.8.0
# !pip install --upgrade docopt==0.6.2
# !pip install --upgrade docopt==0.6.2
# !pip install --upgrade sacrebleu==2.6.0
# !pip install --upgrade nltk==3.9.4
# Out:
# Collecting timeout_decorator==0.5.0
#   Downloading timeout-decorator-0.5.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: timeout_decorator
#   Building wheel for timeout_decorator (setup.py) ... done
#   Created wheel for timeout_decorator: filename=timeout_decorator-0.5.0-py3-none-any.whl size=5006 sha256=1485bd6af1aac912087abd31c9ae37e19107b18d4e2856ff04b4e99343c806c6
#   Stored in directory: /root/.cache/pip/wheels/4d/6a/e3/c4f2cdd67648203ccf069daa31c3935a5c74ec04cccbac9411
# Successfully built timeout_decorator
# Installing collected packages: timeout_decorator
# Successfully installed timeout_decorator-0.5.0
# Collecting numpy==2.4.4
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 141.1 MB/s eta 0:00:0000:010:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.4 which is incompatible.
# Successfully installed numpy-2.4.4
# Collecting scipy==1.17.1
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from scipy==1.17.1) (2.4.4)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 76.9 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# Successfully installed scipy-1.17.1
# Collecting scikit-learn==1.8.0
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (3.6.0)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 102.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed scikit-learn-1.8.0
# Collecting docopt==0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=fb1a72abdaaa9c97105f29b1cea9badff8ffb13aed93ac054bef561b2fded0cc
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt
# Successfully installed docopt-0.6.2
# Requirement already satisfied: docopt==0.6.2 in /usr/local/lib/python3.12/dist-packages (0.6.2)
# Collecting sacrebleu==2.6.0
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Collecting portalocker (from sacrebleu==2.6.0)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu==2.6.0) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu==2.6.0) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu==2.6.0) (2.4.4)
# Collecting colorama (from sacrebleu==2.6.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu==2.6.0) (6.1.1)
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 12.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.2.0 sacrebleu-2.6.0
# Collecting nltk==3.9.4
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.4) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.4) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.4) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.4) (4.67.3)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.5 MB/s eta 0:00:00
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
# Successfully installed nltk-3.9.4

# %% [markdown]
# ## Display the runtimes of each cell

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (75.2.0)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.8.2)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 135.2 MB/s eta 0:00:0000:01
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.20.0
# time: 218 µs (started: 2026-07-19 02:37:54 +00:00)

# %% [markdown]
# ## Cloning GitHub XCS224N-A5 private repository
#
# Unfortunately our Git repositories are based on Git LFS and cannot be cloned properly on Google Drive. Therefore before running the experiments, you could
#
# *   clone our default XCS224N-A5 repository and update manually the modified files to have the latest stage of your development in Google Colab
# *   duplicate our default XCS224N-A5 repository under your GitHub account, and clone it directly in Google Colab. More [here](https://docs.github.com/en/repositories/creating-and-managing-repositories/duplicating-a-repository#).
#
# By default the cells below will use the first option and therefore the default [XCS224N-A5](https://github.com/scpd-proed/XCS224N-A5.git) repository gets cloned.

# %% [markdown]
# Enter your GitHub username and [GitHub Personal Access Token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens) in the fields that will pop up when executing the cell below.

# %%
# !git clone https://github.com/krishnan1159/XCS224N-Assignment5.git
# Out:
# fatal: destination path 'XCS224N-Assignment5' already exists and is not an empty directory.
# time: 103 ms (started: 2026-07-19 02:38:05 +00:00)

# %% [markdown]
# ## Mounting Google Drive locally

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# time: 26 s (started: 2026-07-19 02:38:08 +00:00)

# %% [markdown]
# The required generated files and the log files will be stored in your Google Drive account under `Stanford/XCS224N/A5` folder.

# %%
# %mkdir -p "/content/drive/MyDrive/Stanford/XCS224N/A5/data"
# Out:
# time: 2.31 s (started: 2026-07-19 02:38:36 +00:00)

# %% [markdown]
# ## Run A5 experiments

# %% [markdown]
# Check first that all the basic test cases pass, i.e. you have the latest stage of your work available on Google Colab.

# %%
# %cd "/content/XCS224N-Assignment5/src"
# Out:
# /content/XCS224N-Assignment5/src
# time: 1.54 ms (started: 2026-07-19 02:38:40 +00:00)

# %%
# !python grader.py
# Out:
# ========== START GRADING
# ----- START 1c-0-basic:  check CharCorruptionDataset truncation length
# data has 2768 characters, 26 unique.
# ----- END 1c-0-basic [took 0:00:00.072002 (max allowed 5 seconds), 5.0/5.0 points]
#
# ----- START 1c-1-basic:  check CharCorruptionDataset rearrange
# data has 2586 characters, 26 unique.
# ----- END 1c-1-basic [took 0:00:00.011522 (max allowed 5 seconds), 5.0/5.0 points]
#
# ----- START 1c-2-basic:  check CharCorruptionDataset io
# data has 2704 characters, 26 unique.
# ----- END 1c-2-basic [took 0:00:00.026003 (max allowed 5 seconds), 5.0/5.0 points]
#
# ----- START 1c-3-basic:  check CharCorruptionDataset masked content length
# data has 2611 characters, 26 unique.
# ----- END 1c-3-basic [took 0:00:00.012323 (max allowed 5 seconds), 5.0/5.0 points]
#
# ----- START 1d-0-hidden:  vanilla model similarity
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# number of parameters: 3323392
# ----- END 1d-0-hidden [took 0:00:00.054710 (max allowed 5 seconds), 2.0/2.0 points]
#
# ----- START 1d-1-basic:  correct trainer object initialization for finetune without pretraining
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
# ----- END 1d-1-basic [took 0:00:00.324900 (max allowed 15 seconds), 2.0/2.0 points]
#
# ----- START 1e-0-hidden:   test the dev score for vanilla attention without pretrain
# <class 'AssertionError'>
# 0 not greater than or equal to 1
#   File "/usr/lib/python3.12/unittest/case.py", line 58, in testPartExecutor
#     yield
#   File "/usr/lib/python3.12/unittest/case.py", line 634, in run
#     self._callTestMethod(testMethod)
#   File "/usr/lib/python3.12/unittest/case.py", line 589, in _callTestMethod
#     if method() is not None:
#        ^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 54, in wrapper
#     result = func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 84, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 176, in test_0
#     self.assertGreaterEqual(n_correct, 1)
# ----- END 1e-0-hidden [took 0:00:00.002240 (max allowed 5 seconds), 0/2.0 points]
#
# ----- START 1e-1-hidden:   test the test score for vanilla attention without pretrain
# <class 'AssertionError'>
# 0 not greater than or equal to 1
#   File "/usr/lib/python3.12/unittest/case.py", line 58, in testPartExecutor
#     yield
#   File "/usr/lib/python3.12/unittest/case.py", line 634, in run
#     self._callTestMethod(testMethod)
#   File "/usr/lib/python3.12/unittest/case.py", line 589, in _callTestMethod
#     if method() is not None:
#        ^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 54, in wrapper
#     result = func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 84, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 185, in test_1
#     self.assertGreaterEqual(n_correct, 1)
# ----- END 1e-1-hidden [took 0:00:00.001116 (max allowed 5 seconds), 0/4.0 points]
#
# ----- START 1f-0-basic:  check basic vanilla pretrain trainer object
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
# ----- END 1f-0-basic [took 0:00:00.007664 (max allowed 5 seconds), 7.0/7.0 points]
#
# ----- START 1f-1-hidden:   test the dev score for vanilla attention with pretrain
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# <class 'FileNotFoundError'>
# [Errno 2] No such file or directory: './submission/vanilla.pretrain.dev.predictions'
#   File "/usr/lib/python3.12/unittest/case.py", line 58, in testPartExecutor
#     yield
#   File "/usr/lib/python3.12/unittest/case.py", line 634, in run
#     self._callTestMethod(testMethod)
#   File "/usr/lib/python3.12/unittest/case.py", line 589, in _callTestMethod
#     if method() is not None:
#        ^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 54, in wrapper
#     result = func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 84, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 213, in test_1
#     n_correct, n_total = score_preds(
#                          ^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 26, in score_preds
#     with open(preds_fn, "r", encoding='utf-8') as f_stu:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----- END 1f-1-hidden [took 0:00:00.001162 (max allowed 5 seconds), 0/5.0 points]
#
# ----- START 1f-2-hidden:   test the test score for vanilla attention with pretrain
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# <class 'FileNotFoundError'>
# [Errno 2] No such file or directory: './submission/vanilla.pretrain.test.predictions'
#   File "/usr/lib/python3.12/unittest/case.py", line 58, in testPartExecutor
#     yield
#   File "/usr/lib/python3.12/unittest/case.py", line 634, in run
#     self._callTestMethod(testMethod)
#   File "/usr/lib/python3.12/unittest/case.py", line 589, in _callTestMethod
#     if method() is not None:
#        ^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 54, in wrapper
#     result = func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 84, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 222, in test_2
#     n_correct, n_total = score_preds(
#                          ^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 26, in score_preds
#     with open(preds_fn, "r", encoding='utf-8') as f_stu:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----- END 1f-2-hidden [took 0:00:00.000805 (max allowed 5 seconds), 0/8.0 points]
#
# ----- START 1h-0-hidden:   test the dev score for rope attention with pretrain
# data has 418351 characters, 256 unique.
# number of parameters: 3290624
# <class 'FileNotFoundError'>
# [Errno 2] No such file or directory: './submission/rope.pretrain.dev.predictions'
#   File "/usr/lib/python3.12/unittest/case.py", line 58, in testPartExecutor
#     yield
#   File "/usr/lib/python3.12/unittest/case.py", line 634, in run
#     self._callTestMethod(testMethod)
#   File "/usr/lib/python3.12/unittest/case.py", line 589, in _callTestMethod
#     if method() is not None:
#        ^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 54, in wrapper
#     result = func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 84, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 237, in test_0
#     n_correct, n_total = score_preds(
#                          ^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 26, in score_preds
#     with open(preds_fn, "r", encoding='utf-8') as f_stu:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----- END 1h-0-hidden [took 0:00:00.000807 (max allowed 5 seconds), 0/5.0 points]
#
# ----- START 1h-1-hidden:   test the test score for rope attention with pretrain
# data has 418351 characters, 256 unique.
# number of parameters: 3290624
# <class 'FileNotFoundError'>
# [Errno 2] No such file or directory: './submission/rope.pretrain.test.predictions'
#   File "/usr/lib/python3.12/unittest/case.py", line 58, in testPartExecutor
#     yield
#   File "/usr/lib/python3.12/unittest/case.py", line 634, in run
#     self._callTestMethod(testMethod)
#   File "/usr/lib/python3.12/unittest/case.py", line 589, in _callTestMethod
#     if method() is not None:
#        ^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 54, in wrapper
#     result = func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/graderUtil.py", line 84, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 245, in test_1
#     n_correct, n_total = score_preds(
#                          ^^^^^^^^^^^^
#   File "/content/XCS224N-Assignment5/src/grader.py", line 26, in score_preds
#     with open(preds_fn, "r", encoding='utf-8') as f_stu:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ----- END 1h-1-hidden [took 0:00:00.000778 (max allowed 5 seconds), 0/5.0 points]
#
# Note that the hidden test cases do not check for correctness.
# They are provided for you to verify that the functions do not crash and run within the time limit.
# Points for these parts not assigned by the grader unless the solution is present (indicated by "???").
# ========== END GRADING [31.0/60.0 points + 0/0 extra credit]
# time: 8.23 s (started: 2026-07-19 02:38:42 +00:00)

# %% [markdown]
# ## **Important note**
#
# Uncomment and execute each of the cell below if you want to run the experiments individually!
#
# To keep the costs low, make sure you use the standard available GPU, as there will be no real benefit of using a high end GPU!

# %%
# Run 1
# !bash ./run.sh vanilla_finetune_without_pretrain
# !cp ./submission/vanilla.model.params /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# 2026-07-19 02:38:57.244932: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 02:38:57.312710: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
# epoch 1 iter 7: train loss 3.52468. lr 5.999844e-04: 100% 8/8 [00:02<00:00,  3.37it/s]
# epoch 2 iter 7: train loss 2.67483. lr 5.999351e-04: 100% 8/8 [00:01<00:00,  5.42it/s]
# epoch 3 iter 7: train loss 2.36261. lr 5.998520e-04: 100% 8/8 [00:01<00:00,  5.42it/s]
# epoch 4 iter 7: train loss 2.19229. lr 5.997351e-04: 100% 8/8 [00:01<00:00,  5.42it/s]
# epoch 5 iter 7: train loss 2.09228. lr 5.995844e-04: 100% 8/8 [00:01<00:00,  5.42it/s]
# epoch 6 iter 7: train loss 2.01797. lr 5.993999e-04: 100% 8/8 [00:01<00:00,  5.42it/s]
# epoch 7 iter 7: train loss 1.97576. lr 5.991818e-04: 100% 8/8 [00:01<00:00,  5.42it/s]
# epoch 8 iter 7: train loss 1.92116. lr 5.989299e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 9 iter 7: train loss 1.85095. lr 5.986444e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 10 iter 7: train loss 1.79321. lr 5.983252e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 11 iter 7: train loss 1.74679. lr 5.979723e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 12 iter 7: train loss 1.68924. lr 5.975860e-04: 100% 8/8 [00:01<00:00,  5.39it/s]
# epoch 13 iter 7: train loss 1.61704. lr 5.971660e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 14 iter 7: train loss 1.53761. lr 5.967127e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 15 iter 7: train loss 1.46053. lr 5.962258e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 16 iter 7: train loss 1.41007. lr 5.957056e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 17 iter 7: train loss 1.33057. lr 5.951521e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 18 iter 7: train loss 1.25991. lr 5.945654e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 19 iter 7: train loss 1.18266. lr 5.939454e-04: 100% 8/8 [00:01<00:00,  5.39it/s]
# epoch 20 iter 7: train loss 1.12899. lr 5.932923e-04: 100% 8/8 [00:01<00:00,  5.39it/s]
# epoch 21 iter 7: train loss 1.07697. lr 5.926062e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 22 iter 7: train loss 1.02296. lr 5.918871e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# epoch 23 iter 7: train loss 0.99466. lr 5.911352e-04: 100% 8/8 [00:01<00:00,  5.39it/s]
# epoch 24 iter 7: train loss 0.95207. lr 5.903504e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# epoch 25 iter 7: train loss 0.90171. lr 5.895329e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 26 iter 7: train loss 0.84576. lr 5.886828e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# epoch 27 iter 7: train loss 0.85415. lr 5.878002e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 28 iter 7: train loss 0.81154. lr 5.868851e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# epoch 29 iter 7: train loss 0.79965. lr 5.859378e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 30 iter 7: train loss 0.73851. lr 5.849582e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 31 iter 7: train loss 0.73847. lr 5.839465e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 32 iter 7: train loss 0.71096. lr 5.829028e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# epoch 33 iter 7: train loss 0.67122. lr 5.818272e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# epoch 34 iter 7: train loss 0.68758. lr 5.807199e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 35 iter 7: train loss 0.68469. lr 5.795810e-04: 100% 8/8 [00:01<00:00,  5.37it/s]
# epoch 36 iter 7: train loss 0.64729. lr 5.784106e-04: 100% 8/8 [00:01<00:00,  5.36it/s]
# epoch 37 iter 7: train loss 0.62830. lr 5.772087e-04: 100% 8/8 [00:01<00:00,  5.35it/s]
# epoch 38 iter 7: train loss 0.61102. lr 5.759757e-04: 100% 8/8 [00:01<00:00,  5.36it/s]
# epoch 39 iter 7: train loss 0.60517. lr 5.747116e-04: 100% 8/8 [00:01<00:00,  5.36it/s]
# epoch 40 iter 7: train loss 0.59467. lr 5.734165e-04: 100% 8/8 [00:01<00:00,  5.35it/s]
# epoch 41 iter 7: train loss 0.58783. lr 5.720906e-04: 100% 8/8 [00:01<00:00,  5.35it/s]
# epoch 42 iter 7: train loss 0.54546. lr 5.707341e-04: 100% 8/8 [00:01<00:00,  5.35it/s]
# epoch 43 iter 7: train loss 0.53568. lr 5.693470e-04: 100% 8/8 [00:01<00:00,  5.36it/s]
# epoch 44 iter 7: train loss 0.54287. lr 5.679296e-04: 100% 8/8 [00:01<00:00,  5.34it/s]
# epoch 45 iter 7: train loss 0.53839. lr 5.664820e-04: 100% 8/8 [00:01<00:00,  5.34it/s]
# epoch 46 iter 7: train loss 0.52596. lr 5.650044e-04: 100% 8/8 [00:01<00:00,  5.34it/s]
# epoch 47 iter 7: train loss 0.49397. lr 5.634970e-04: 100% 8/8 [00:01<00:00,  5.34it/s]
# epoch 48 iter 7: train loss 0.50732. lr 5.619598e-04: 100% 8/8 [00:01<00:00,  5.33it/s]
# epoch 49 iter 7: train loss 0.47402. lr 5.603932e-04: 100% 8/8 [00:01<00:00,  5.34it/s]
# epoch 50 iter 7: train loss 0.46776. lr 5.587972e-04: 100% 8/8 [00:01<00:00,  5.33it/s]
# epoch 51 iter 7: train loss 0.45436. lr 5.571720e-04: 100% 8/8 [00:01<00:00,  5.34it/s]
# epoch 52 iter 7: train loss 0.45576. lr 5.555179e-04: 100% 8/8 [00:01<00:00,  5.33it/s]
# epoch 53 iter 7: train loss 0.46269. lr 5.538350e-04: 100% 8/8 [00:01<00:00,  5.32it/s]
# epoch 54 iter 7: train loss 0.41525. lr 5.521235e-04: 100% 8/8 [00:01<00:00,  5.32it/s]
# epoch 55 iter 7: train loss 0.41381. lr 5.503835e-04: 100% 8/8 [00:01<00:00,  5.31it/s]
# epoch 56 iter 7: train loss 0.42660. lr 5.486154e-04: 100% 8/8 [00:01<00:00,  5.32it/s]
# epoch 57 iter 7: train loss 0.38164. lr 5.468193e-04: 100% 8/8 [00:01<00:00,  5.32it/s]
# epoch 58 iter 7: train loss 0.40568. lr 5.449953e-04: 100% 8/8 [00:01<00:00,  5.31it/s]
# epoch 59 iter 7: train loss 0.37808. lr 5.431438e-04: 100% 8/8 [00:01<00:00,  5.31it/s]
# epoch 60 iter 7: train loss 0.38776. lr 5.412648e-04: 100% 8/8 [00:01<00:00,  5.30it/s]
# epoch 61 iter 7: train loss 0.35962. lr 5.393587e-04: 100% 8/8 [00:01<00:00,  5.31it/s]
# epoch 62 iter 7: train loss 0.34913. lr 5.374256e-04: 100% 8/8 [00:01<00:00,  5.30it/s]
# epoch 63 iter 7: train loss 0.31639. lr 5.354657e-04: 100% 8/8 [00:01<00:00,  5.30it/s]
# epoch 64 iter 7: train loss 0.31709. lr 5.334794e-04: 100% 8/8 [00:01<00:00,  5.30it/s]
# epoch 65 iter 7: train loss 0.31155. lr 5.314667e-04: 100% 8/8 [00:01<00:00,  5.30it/s]
# epoch 66 iter 7: train loss 0.31541. lr 5.294279e-04: 100% 8/8 [00:01<00:00,  5.28it/s]
# epoch 67 iter 7: train loss 0.27499. lr 5.273633e-04: 100% 8/8 [00:01<00:00,  5.29it/s]
# epoch 68 iter 7: train loss 0.28235. lr 5.252731e-04: 100% 8/8 [00:01<00:00,  5.29it/s]
# epoch 69 iter 7: train loss 0.25945. lr 5.231575e-04: 100% 8/8 [00:01<00:00,  5.28it/s]
# epoch 70 iter 7: train loss 0.25211. lr 5.210167e-04: 100% 8/8 [00:01<00:00,  5.29it/s]
# epoch 71 iter 7: train loss 0.23401. lr 5.188511e-04: 100% 8/8 [00:01<00:00,  5.29it/s]
# epoch 72 iter 7: train loss 0.23507. lr 5.166608e-04: 100% 8/8 [00:01<00:00,  5.27it/s]
# epoch 73 iter 7: train loss 0.20900. lr 5.144461e-04: 100% 8/8 [00:01<00:00,  5.27it/s]
# epoch 74 iter 7: train loss 0.20039. lr 5.122072e-04: 100% 8/8 [00:01<00:00,  5.27it/s]
# epoch 75 iter 7: train loss 0.19194. lr 5.099444e-04: 100% 8/8 [00:01<00:00,  5.27it/s]
# time: 2min 8s (started: 2026-07-19 02:38:54 +00:00)

# %%
# Run 2
# !bash ./run.sh vanilla_eval_dev_without_pretrain
# !cp ./submission/vanilla.nopretrain.dev.predictions /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# 2026-07-19 02:42:59.789830: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 02:42:59.859522: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 500it [00:48, 10.33it/s]
# Correct: 8.0 out of 500.0: 1.6%
# time: 57.4 s (started: 2026-07-19 02:42:57 +00:00)

# %%
# Run 3
# !bash ./run.sh vanilla_eval_test_without_pretrain
# !cp ./submission/vanilla.nopretrain.test.predictions /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# 2026-07-19 02:45:18.928293: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 02:45:18.998751: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 437it [00:42, 10.37it/s]
# !!! No ground truth is provided, this will be done on the autograder, returning (0,0)
# Predictions written to ./submission/vanilla.nopretrain.test.predictions; no targets provided
# time: 51.1 s (started: 2026-07-19 02:45:16 +00:00)

# %%
# Run 4
# !bash ./run.sh vanilla_pretrain
# !cp ./submission/vanilla.pretrain.params /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# Starting Vanilla Pretrain: ~ 1 Hours
# 2026-07-19 02:46:19.684587: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 02:46:19.756863: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
# epoch 1 iter 22: train loss 3.44680. lr 5.999650e-03: 100% 23/23 [00:02<00:00,  9.07it/s]
# epoch 2 iter 22: train loss 3.43578. lr 5.998559e-03: 100% 23/23 [00:02<00:00, 10.86it/s]
# epoch 3 iter 22: train loss 3.04818. lr 5.996729e-03: 100% 23/23 [00:02<00:00, 10.85it/s]
# epoch 4 iter 22: train loss 2.92763. lr 5.994159e-03: 100% 23/23 [00:02<00:00, 10.82it/s]
# epoch 5 iter 22: train loss 2.86495. lr 5.990850e-03: 100% 23/23 [00:02<00:00, 10.85it/s]
# epoch 6 iter 22: train loss 2.82014. lr 5.986803e-03: 100% 23/23 [00:02<00:00, 10.80it/s]
# epoch 7 iter 22: train loss 2.80283. lr 5.982019e-03: 100% 23/23 [00:02<00:00, 10.79it/s]
# epoch 8 iter 22: train loss 2.78847. lr 5.976498e-03: 100% 23/23 [00:02<00:00, 10.82it/s]
# epoch 9 iter 22: train loss 2.76180. lr 5.970243e-03: 100% 23/23 [00:02<00:00, 10.81it/s]
# epoch 10 iter 22: train loss 2.74128. lr 5.963256e-03: 100% 23/23 [00:02<00:00, 10.81it/s]
# epoch 11 iter 22: train loss 2.71100. lr 5.955536e-03: 100% 23/23 [00:02<00:00, 10.78it/s]
# epoch 12 iter 22: train loss 2.71413. lr 5.947088e-03: 100% 23/23 [00:02<00:00, 10.77it/s]
# epoch 13 iter 22: train loss 2.66524. lr 5.937912e-03: 100% 23/23 [00:02<00:00, 10.75it/s]
# epoch 14 iter 22: train loss 2.67965. lr 5.928010e-03: 100% 23/23 [00:02<00:00, 10.76it/s]
# epoch 15 iter 22: train loss 2.65729. lr 5.917387e-03: 100% 23/23 [00:02<00:00, 10.76it/s]
# epoch 16 iter 22: train loss 2.61282. lr 5.906043e-03: 100% 23/23 [00:02<00:00, 10.75it/s]
# epoch 17 iter 22: train loss 2.64329. lr 5.893982e-03: 100% 23/23 [00:02<00:00, 10.75it/s]
# epoch 18 iter 22: train loss 2.62746. lr 5.881207e-03: 100% 23/23 [00:02<00:00, 10.75it/s]
# epoch 19 iter 22: train loss 2.62625. lr 5.867720e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 20 iter 22: train loss 2.59471. lr 5.853526e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 21 iter 22: train loss 2.61011. lr 5.838628e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 22 iter 22: train loss 2.60377. lr 5.823029e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 23 iter 22: train loss 2.57854. lr 5.806733e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 24 iter 22: train loss 2.58754. lr 5.789745e-03: 100% 23/23 [00:02<00:00, 10.70it/s]
# epoch 25 iter 22: train loss 2.55828. lr 5.772068e-03: 100% 23/23 [00:02<00:00, 10.68it/s]
# epoch 26 iter 22: train loss 2.54808. lr 5.753707e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 27 iter 22: train loss 2.54853. lr 5.734667e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 28 iter 22: train loss 2.56710. lr 5.714951e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 29 iter 22: train loss 2.53751. lr 5.694565e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 30 iter 22: train loss 2.51482. lr 5.673515e-03: 100% 23/23 [00:02<00:00, 10.68it/s]
# epoch 31 iter 22: train loss 2.49531. lr 5.651804e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch 32 iter 22: train loss 2.52887. lr 5.629439e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch 33 iter 22: train loss 2.52324. lr 5.606425e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch 34 iter 22: train loss 2.48342. lr 5.582768e-03: 100% 23/23 [00:02<00:00, 10.65it/s]
# epoch 35 iter 22: train loss 2.48635. lr 5.558474e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch 36 iter 22: train loss 2.50091. lr 5.533548e-03: 100% 23/23 [00:02<00:00, 10.65it/s]
# epoch 37 iter 22: train loss 2.51940. lr 5.507996e-03: 100% 23/23 [00:02<00:00, 10.68it/s]
# epoch 38 iter 22: train loss 2.49960. lr 5.481826e-03: 100% 23/23 [00:02<00:00, 10.71it/s]
# epoch 39 iter 22: train loss 2.48416. lr 5.455043e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 40 iter 22: train loss 2.46406. lr 5.427655e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 41 iter 22: train loss 2.45262. lr 5.399667e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 42 iter 22: train loss 2.43992. lr 5.371086e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 43 iter 22: train loss 2.42242. lr 5.341921e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 44 iter 22: train loss 2.42993. lr 5.312178e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 45 iter 22: train loss 2.39867. lr 5.281864e-03: 100% 23/23 [00:02<00:00, 10.75it/s]
# epoch 46 iter 22: train loss 2.43145. lr 5.250987e-03: 100% 23/23 [00:02<00:00, 10.76it/s]
# epoch 47 iter 22: train loss 2.38037. lr 5.219554e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 48 iter 22: train loss 2.37418. lr 5.187574e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 49 iter 22: train loss 2.32914. lr 5.155053e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 50 iter 22: train loss 2.30405. lr 5.122001e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 51 iter 22: train loss 2.32402. lr 5.088425e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 52 iter 22: train loss 2.28308. lr 5.054334e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 53 iter 22: train loss 2.28169. lr 5.019735e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 54 iter 22: train loss 2.27426. lr 4.984638e-03: 100% 23/23 [00:02<00:00, 10.75it/s]
# epoch 55 iter 22: train loss 2.26387. lr 4.949052e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 56 iter 22: train loss 2.22095. lr 4.912984e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 57 iter 22: train loss 2.24698. lr 4.876444e-03: 100% 23/23 [00:02<00:00, 10.73it/s]
# epoch 58 iter 22: train loss 2.15672. lr 4.839441e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 59 iter 22: train loss 2.17106. lr 4.801984e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 60 iter 22: train loss 2.16116. lr 4.764083e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 61 iter 22: train loss 2.10537. lr 4.725746e-03: 100% 23/23 [00:02<00:00, 10.72it/s]
# epoch 62 iter 22: train loss 2.12069. lr 4.686983e-03: 100% 23/23 [00:02<00:00, 10.70it/s]
# epoch 63 iter 22: train loss 2.11295. lr 4.647803e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 64 iter 22: train loss 2.11429. lr 4.608217e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 65 iter 22: train loss 2.05795. lr 4.568234e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 66 iter 22: train loss 2.03261. lr 4.527865e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 67 iter 22: train loss 2.03265. lr 4.487118e-03: 100% 23/23 [00:02<00:00, 10.68it/s]
# epoch 68 iter 22: train loss 2.00402. lr 4.446003e-03: 100% 23/23 [00:02<00:00, 10.68it/s]
# epoch 69 iter 22: train loss 1.94334. lr 4.404533e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 70 iter 22: train loss 1.93976. lr 4.362715e-03: 100% 23/23 [00:02<00:00, 10.69it/s]
# epoch 71 iter 22: train loss 1.96667. lr 4.320561e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch 72 iter 22: train loss 1.92134. lr 4.278081e-03: 100% 23/23 [00:02<00:00, 10.65it/s]
# epoch 73 iter 22: train loss 1.90432. lr 4.235286e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch 74 iter 22: train loss 1.89037. lr 4.192186e-03: 100% 23/23 [00:02<00:00, 10.65it/s]
# epoch 75 iter 22: train loss 1.87065. lr 4.148792e-03: 100% 23/23 [00:02<00:00, 10.66it/s]
# epoch
-04: 100% 23/23 [00:02<00:00, 10.71it/s]
# epoch 649 iter 22: train loss 0.57632. lr 8.476278e-04: 100% 23/23 [00:02<00:00, 10.71it/s]
# epoch 650 iter 22: train loss 0.54262. lr 8.807231e-04: 100% 23/23 [00:02<00:00, 10.74it/s]
# time: 23min 28s (started: 2026-07-19 02:46:17 +00:00)

# %%
# Run 5
# !bash ./run.sh vanilla_finetune_with_pretrain
# !cp ./submission/vanilla.finetune.params /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# 2026-07-19 03:17:45.424047: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 03:17:45.493562: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
# epoch 1 iter 7: train loss 0.76496. lr 5.999844e-04: 100% 8/8 [00:01<00:00,  4.14it/s]
# epoch 2 iter 7: train loss 0.63051. lr 5.999351e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 3 iter 7: train loss 0.56607. lr 5.998520e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 4 iter 7: train loss 0.49097. lr 5.997351e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 5 iter 7: train loss 0.43929. lr 5.995844e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 6 iter 7: train loss 0.40504. lr 5.993999e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 7 iter 7: train loss 0.37268. lr 5.991818e-04: 100% 8/8 [00:01<00:00,  5.41it/s]
# epoch 8 iter 7: train loss 0.32237. lr 5.989299e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 9 iter 7: train loss 0.29107. lr 5.986444e-04: 100% 8/8 [00:01<00:00,  5.40it/s]
# epoch 10 iter 7: train loss 0.24500. lr 5.983252e-04: 100% 8/8 [00:01<00:00,  5.38it/s]
# time: 25.3 s (started: 2026-07-19 03:17:43 +00:00)

# %%
# Run 6
# !bash ./run.sh vanilla_eval_dev_with_pretrain
# !cp ./submission/vanilla.pretrain.dev.predictions /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# 2026-07-19 03:18:24.086171: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 03:18:24.154748: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 500it [00:49, 10.20it/s]
# Correct: 82.0 out of 500.0: 16.400000000000002%
# time: 57.4 s (started: 2026-07-19 03:18:21 +00:00)

# %%
# Run 7
# !bash ./run.sh vanilla_eval_test_with_pretrain
# !cp ./submission/vanilla.pretrain.test.predictions /content/drive/MyDrive/Stanford/XCS224N/A5/data/
# Out:
# 2026-07-19 03:19:28.006867: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-19 03:19:28.079287: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 437it [00:41, 10.62it/s]
# !!! No ground truth is provided, this will be done on the autograder, returning (0,0)
# Predictions written to ./submission/vanilla.pretrain.test.predictions; no targets provided
# time: 49.5 s (started: 2026-07-19 03:19:25 +00:00)

# %%
# Run 8
# !bash ./run.sh rope_pretrain
# !cp ./submission/rope.pretrain.params /content/drive/MyDrive/Stanford/XCS224N/A5/data/

# %%
# Run 9
# !bash ./run.sh rope_finetune_with_pretrain
# !cp ./submission/rope.finetune.params /content/drive/MyDrive/Stanford/XCS224N/A5/data/

# %%
# Run 10
# !bash ./run.sh rope_eval_dev_with_pretrain
# !cp ./submission/rope.pretrain.dev.predictions /content/drive/MyDrive/Stanford/XCS224N/A5/data/

# %%
# Run 11
# !bash ./run.sh rope_eval_test_with_pretrain
# !cp ./submission/rope.pretrain.test.predictions /content/drive/MyDrive/Stanford/XCS224N/A5/data/

# %% [markdown]
# # Submission
#
# The experiments will generate the files in your Google Drive account under `Stanford/XCS224N/A5` folder. Revert to the `A5.pdf` to get the full list of files and folders you would need to download from the mentioned GDrive folder and generate a submission!
